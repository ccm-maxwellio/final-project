# %% [markdown]
# # Title: Project 3 Milestone #2
# # Name: Maxwell Yung
# # Date: 4/21/25

# %% [markdown]
# Import pandas, read in data file

# %%
import pandas as pd
datafile = "Recalls_Data.csv"
df = pd.read_csv(datafile)

# %% [markdown]
# Now analyze raw data

# %%
df
# Out:
#       Report Received Date   NHTSA ID  \
# 0               04/16/2026  26E021000
# 1               04/16/2026  26V244000
# 2               04/15/2026  26V241000
# 3               04/14/2026  26V237000
# 4               04/13/2026  26V234000
# ...                    ...        ...
# 29915           09/29/1966  66V003000
# 29916           09/19/1966  66V178000
# 29917           01/19/1966  66V032001
# 29918           01/19/1966  66V032003
# 29919           01/19/1966  66V032004
#
#                                              Recall Link  \
# 0      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# ...                                                  ...
# 29915  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Report Received Date   NHTSA ID  \
# 0               04/16/2026  26E021000
# 1               04/16/2026  26V244000
# 2               04/15/2026  26V241000
# 3               04/14/2026  26V237000
# 4               04/13/2026  26V234000
# ...                    ...        ...
# 29915           09/29/1966  66V003000
# 29916           09/19/1966  66V178000
# 29917           01/19/1966  66V032001
# 29918           01/19/1966  66V032003
# 29919           01/19/1966  66V032004
#
#                                              Recall Link  \
# 0      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4      Go to Recall (https://www.nhtsa.gov/recalls?nh...
# ...                                                  ...
# 29915  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# ...

# %%
df.columns
# Out:
# Index(['Report Received Date', 'NHTSA ID', 'Recall Link', 'Manufacturer',
#        'Subject', 'Component', 'Mfr Campaign Number', 'Recall Type',
#        'Potentially Affected', 'Recall Description', 'Consequence Summary',
#        'Corrective Action', 'Park Outside Advisory ', 'Do Not Drive Advisory',
#        'Completion Rate % (Blank - Not Reported)'],
#       dtype='object')

# %%
df.shape
# Out:
# (29920, 15)

# %%
df.dtypes
# Out:
# Report Received Date                         object
# NHTSA ID                                     object
# Recall Link                                  object
# Manufacturer                                 object
# Subject                                      object
# Component                                    object
# Mfr Campaign Number                          object
# Recall Type                                  object
# Potentially Affected                          int64
# Recall Description                           object
# Consequence Summary                          object
# Corrective Action                            object
# Park Outside Advisory                        object
# Do Not Drive Advisory                        object
# Completion Rate % (Blank - Not Reported)    float64
# dtype: object

# %%
df.head()
# Out:
#   Report Received Date   NHTSA ID  \
# 0           04/16/2026  26E021000
# 1           04/16/2026  26V244000
# 2           04/15/2026  26V241000
# 3           04/14/2026  26V237000
# 4           04/13/2026  26V234000
#
#                                          Recall Link  \
# 0  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 1  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 2  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 3  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 4  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                     Manufacturer  \
# 0         Chrysler (FCA US, LLC)
# 1         Chrysler (FCA US, LLC)
# 2     Winnebago Industries, Inc.
# 3             Ford Motor Company
# 4  Harley-Davidson Motor Company
#
#                                              Subject  \
# 0  Engine Failure May Cause Fire or Loss of Drive...
# 1     Loss of Electronic Stability Control/FMVSS 126
# 2                  Missing Side Reflectors/FMVSS 108
# ...

# %%
df.tail()
# Out:
#       Report Received Date   NHTSA ID  \
# 29915           09/29/1966  66V003000
# 29916           09/19/1966  66V178000
# 29917           01/19/1966  66V032001
# 29918           01/19/1966  66V032003
# 29919           01/19/1966  66V032004
#
#                                              Recall Link  \
# 29915  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 29916  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 29917  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 29918  Go to Recall (https://www.nhtsa.gov/recalls?nh...
# 29919  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                            Manufacturer  \
# 29915  Honda (American Honda Motor Co.)
# 29916             RENAULT, INCORPORATED
# 29917               General Motors, LLC
# 29918               General Motors, LLC
# 29919               General Motors, LLC
#
#                                         Subject                  Component  \
# ...

# %%
df.sample()
# Out:
#       Report Received Date   NHTSA ID  \
# 10545           06/21/2016  16V452000
#
#                                              Recall Link  \
# 10545  Go to Recall (https://www.nhtsa.gov/recalls?nh...
#
#                     Manufacturer                                Subject  \
# 10545  International Motors, LLC  Seat May Separate From the Base Frame
#
#       Component Mfr Campaign Number Recall Type  Potentially Affected  \
# 10545       NaN   NR (Not Reported)     Vehicle                     5
#
#                                       Recall Description  \
# 10545  Navistar, Inc. (Navistar) is recalling certain...
#
#                                      Consequence Summary  \
# 10545  In the event of a crash, the seat can separate...
#
#                                        Corrective Action  \
# 10545  Navistar has already completed the repair work...
#
#       Park Outside Advisory  Do Not Drive Advisory  \
# 10545                     No                    No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29920 entries, 0 to 29919
# Data columns (total 15 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Report Received Date                      29920 non-null  object
#  1   NHTSA ID                                  29920 non-null  object
#  2   Recall Link                               29920 non-null  object
#  3   Manufacturer                              29920 non-null  object
#  4   Subject                                   29920 non-null  object
#  5   Component                                 22322 non-null  object
#  6   Mfr Campaign Number                       29681 non-null  object
#  7   Recall Type                               29920 non-null  object
#  8   Potentially Affected                      29920 non-null  int64
#  9   Recall Description                        27519 non-null  object
# ...
